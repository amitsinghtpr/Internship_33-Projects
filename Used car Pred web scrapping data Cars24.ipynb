# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing Chromedriver
driver=webdriver.Chrome(r'"C:\Users\amits\Desktop\chromedriver_win32\chromedriver.exe"')

# %%
url='https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001'
driver.get(url)

# %%
#Scrapping all the details

# %%
brand=[]
brand_name=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    
    for i in brand_name:
        brand.append(i.text)
        

except NoSuchElementException:
    
    brand.append('Not Present')

# %%
brand
# Out:
# ['2020 KIA SELTOS',
#  '2020 KIA SELTOS',
#  '2019 Hyundai Grand i10',
#  '2011 Maruti Alto',
#  '2019 Hyundai Grand i10',
#  '2014 Maruti Wagon R Stingray',
#  '2020 KIA SONET',
#  '2022 Maruti New Wagon-R',
#  '2009 Maruti Swift Dzire',
#  '2020 KIA SELTOS',
#  '2020 KIA SELTOS',
#  '2022 KIA CARENS',
#  '2011 Maruti Wagon R 1.0',
#  '2021 Maruti Swift',
#  '2021 Hyundai NEW I20',
#  '2011 Maruti Wagon R 1.0',
#  '2010 Maruti Alto',
#  '2019 KIA SELTOS',
#  '2019 KIA SELTOS',
#  '2011 Maruti Wagon R 1.0',
#  '2015 Hyundai Elite i20',
#  '2018 Hyundai Eon',
#  '2020 Tata ALTROZ',
#  '2021 Maruti Celerio',
#  '2020 KIA SELTOS',
#  '2022 Skoda KUSHAQ',
#  '2021 Maruti New Wagon-R',
#  '2019 KIA SELTOS',
#  '2021 KIA SONET',
#  '2019 KIA SELTOS',
#  '2020 KIA SONET',
#  '2021 Hyundai VENUE',
#  '2020 KIA SELTOS',
#  '2019 KIA SELTOS',
#  '2015 Toyota Camry',
#  '2021 Maruti New Wagon-R',
#  '2011 Maruti Swift',
#  '2012 Hyundai i10',
#  '2021 Hyundai VENUE',
#  '2022 Renault Kiger',
# ...

# %% [raw]
# Since there  are three data column store in single class hence we are extracting  the data by each Process.

# %%
Manufacturing_year = []
for model in brand:
    year = int(model.split()[0])
    Manufacturing_year.append(year)
    
Manufacturing_year
# Out:
# [2020,
#  2020,
#  2019,
#  2011,
#  2019,
#  2014,
#  2020,
#  2022,
#  2009,
#  2020,
#  2020,
#  2022,
#  2011,
#  2021,
#  2021,
#  2011,
#  2010,
#  2019,
#  2019,
#  2011,
#  2015,
#  2018,
#  2020,
#  2021,
#  2020,
#  2022,
#  2021,
#  2019,
#  2021,
#  2019,
#  2020,
#  2021,
#  2020,
#  2019,
#  2015,
#  2021,
#  2011,
#  2012,
#  2021,
#  2022,
#  2021,
#  2020,
#  2019,
#  2011,
#  2019,
#  2012,
#  2013,
#  2013,
#  2015,
#  2013,
#  2020,
#  2012,
#  2021,
#  2012,
#  2020,
#  2021,
#  2021,
#  2014,
#  2013,
#  2021,
#  2014,
#  2019,
#  2012,
#  2014,
#  2009,
#  2020,
#  2021,
#  2018,
#  2014,
#  2022,
#  2014,
#  2019,
#  2019,
#  2021,
#  2020,
#  2021,
#  2021,
#  2021,
#  2011,
#  2021,
#  2022,
#  2018,
#  2021,
#  2010,
#  2015,
#  2020,
#  2011,
#  2022,
#  2010,
#  2018,
#  2021,
#  2021,
#  2019,
#  2013,
#  2018,
#  2018,
#  2014,
#  2020,
#  2021,
#  2012,
#  2021,
#  2013,
#  2016,
#  2021,
#  2021,
#  2014,
#  2015,
#  2013,
#  2021,
#  2022,
#  2015,
# ...

# %%
len(Manufacturing_year)
# Out:
# 1239

# %%
Brands=[]

for model in brand:
    brand = model.split()[1]
    Brands.append(brand)
Brands
# Out:
# ['KIA',
#  'KIA',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'Maruti',
#  'KIA',
#  'KIA',
#  'KIA',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'KIA',
#  'KIA',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Tata',
#  'Maruti',
#  'KIA',
#  'Skoda',
#  'Maruti',
#  'KIA',
#  'KIA',
#  'KIA',
#  'KIA',
#  'Hyundai',
#  'KIA',
#  'KIA',
#  'Toyota',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Renault',
#  'Renault',
#  'Toyota',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Renault',
#  'Hyundai',
#  'KIA',
#  'Maruti',
#  'Honda',
#  'Maruti',
#  'Renault',
#  'Tata',
#  'Hyundai',
#  'Hyundai',
#  'Renault',
#  'Honda',
#  'Honda',
#  'Renault',
#  'Renault',
#  'Hyundai',
#  'Renault',
#  'Hyundai',
#  'Renault',
#  'Hyundai',
# ...

# %%
len(Brands)
# Out:
# 1239

# %%
Model=[]

for model in brand:
    brand = model.split()[2]
    Model.append(brand)
Model
# Out:
# ['SELTOS',
#  'SELTOS',
#  'Grand',
#  'Alto',
#  'Grand',
#  'Wagon',
#  'SONET',
#  'New',
#  'Swift',
#  'SELTOS',
#  'SELTOS',
#  'CARENS',
#  'Wagon',
#  'Swift',
#  'NEW',
#  'Wagon',
#  'Alto',
#  'SELTOS',
#  'SELTOS',
#  'Wagon',
#  'Elite',
#  'Eon',
#  'ALTROZ',
#  'Celerio',
#  'SELTOS',
#  'KUSHAQ',
#  'New',
#  'SELTOS',
#  'SONET',
#  'SELTOS',
#  'SONET',
#  'VENUE',
#  'SELTOS',
#  'SELTOS',
#  'Camry',
#  'New',
#  'Swift',
#  'i10',
#  'VENUE',
#  'Kiger',
#  'Kiger',
#  'URBAN',
#  'Verna',
#  'i10',
#  'Swift',
#  'Swift',
#  'i10',
#  'i20',
#  'Alto',
#  'Wagon',
#  'SELTOS',
#  'A',
#  'SELTOS',
#  'Alto',
#  'SELTOS',
#  'Swift',
#  'NEW',
#  'i20',
#  'Wagon',
#  'Kwid',
#  'Grand',
#  'SELTOS',
#  'A',
#  'City',
#  'A',
#  'Kwid',
#  'Safari',
#  'Grand',
#  'Eon',
#  'Kiger',
#  'City',
#  'City',
#  'Kwid',
#  'Kwid',
#  'AURA',
#  'Kiger',
#  'AURA',
#  'Kiger',
#  'i10',
#  'New',
#  'Kwid',
#  'Redi',
#  'Redi',
#  'Wagon',
#  'Ecosport',
#  'New',
# ...

# %%
len(Model)
# Out:
# 1239

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"cvakB")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['GTX+',
#  'GTX',
#  'MAGNA',
#  'LXI',
#  'MAGNA',
#  'VXI',
#  'GTX',
#  'LXI',
#  'VXI',
#  'HTX',
#  'GTX',
#  'LUXURY',
#  'VXI',
#  'LXI',
#  'MAGNA',
#  'LXI',
#  'LXI',
#  'HTK',
#  'HTX',
#  'VXI',
#  'SPORTZ',
#  'ERA',
#  'XZ',
#  'VXI',
#  'GTX',
#  'STYLE',
#  'LXI',
#  'HTK',
#  'GTX',
#  'HTK',
#  'GTX',
#  'S',
#  'HTK',
#  'HTK',
#  '2.5',
#  'LXI',
#  'LXI',
#  'SPORTZ',
#  'S',
#  'RXZ',
#  'RXL',
#  'Premium',
#  '1.6',
#  'ERA',
#  'LXI',
#  'VXI',
#  'MAGNA',
#  'SPORTZ',
#  'VXI',
#  'VXI',
#  'HTX',
#  'VXI',
#  'HTX',
#  'LXI',
#  'HTK',
#  'VXI',
#  'MAGNA',
#  'SPORTZ',
#  'VXI',
#  '1.0',
#  'ASTA',
#  'GTX',
#  'VXI',
#  'VX',
#  'VXI',
#  '1.0',
#  'XZA+',
#  'MAGNA',
#  'MAGNA',
#  'RXT',
#  '1.5L',
#  'ZX',
#  '1.0',
#  'RXL',
#  'S',
#  'RXT',
#  'S',
#  'RXZ',
#  'MAGNA',
#  '1.0',
#  '1.0',
#  '1.0',
#  'T',
#  'VXI',
#  '1.5',
#  'VXI',
#  'VXI',
#  'N8',
#  'VXI',
#  'LXI',
#  'PREMIUM',
#  'SPORTZ',
#  'VXI',
#  'S',
#  'LXI',
#  'V',
#  'VXI',
# ...

# %%
len(Variant)
# Out:
# 1239

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['5,999 km',
#  '9,417 km',
#  '19,964 km',
#  '12,030 km',
#  '20,969 km',
#  '68,674 km',
#  '12,461 km',
#  '3,028 km',
#  '26,645 km',
#  '10,678 km',
#  '18,469 km',
#  '3,084 km',
#  '22,754 km',
#  '12,742 km',
#  '3,011 km',
#  '46,077 km',
#  '55,637 km',
#  '25,750 km',
#  '19,207 km',
#  '33,043 km',
#  '73,060 km',
#  '16,578 km',
#  '23,721 km',
#  '10,518 km',
#  '28,506 km',
#  '2,696 km',
#  '3,897 km',
#  '39,585 km',
#  '6,978 km',
#  '24,991 km',
#  '12,835 km',
#  '6,059 km',
#  '49,350 km',
#  '53,070 km',
#  '93,626 km',
#  '9,521 km',
#  '73,738 km',
#  '50,220 km',
#  '12,717 km',
#  '2,461 km',
#  '23,318 km',
#  '22,874 km',
#  '59,449 km',
#  '33,360 km',
#  '1,994 km',
#  '45,557 km',
#  '87,829 km',
#  '56,073 km',
#  '34,855 km',
#  '21,135 km',
#  '26,495 km',
#  '84,057 km',
#  '60,147 km',
#  '30,029 km',
#  '36,352 km',
#  '24,856 km',
#  '16,818 km',
#  '58,879 km',
#  '28,836 km',
#  '10,089 km',
#  '57,770 km',
#  '13,672 km',
#  '31,953 km',
# ...

# %%
len(Driven_kilometers)
# Out:
# 1239

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
len(No_of_owners)
# Out:
# 1239

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
# ...

# %%
len(Fuel)
# Out:
# 1239

# %%
len(Location)
# Out:
# 1239

# %%
location=['New Delhi']

# %%
Location=location*1239

# %%
Location
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹17,22,000',
#  '₹16,81,000',
#  '₹5,03,000',
#  '₹1,74,000',
#  '₹5,28,000',
#  '₹2,64,000',
#  '',
#  '₹5,26,000',
#  '₹2,06,000',
#  '',
#  '',
#  '',
#  '₹2,58,000',
#  '₹5,90,000',
#  '₹7,23,000',
#  '₹2,10,000',
#  '₹1,71,000',
#  '',
#  '',
#  '₹2,79,000',
#  '₹4,33,000',
#  '₹3,23,000',
#  '',
#  '₹4,86,000',
#  '',
#  '',
#  '₹5,17,000',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '₹5,04,000',
#  '₹2,70,000',
#  '₹2,63,000',
#  '',
#  '',
#  '₹6,76,000',
#  '',
#  '',
#  '₹2,16,000',
#  '₹5,66,000',
#  '₹3,31,000',
#  '₹2,75,000',
#  '₹3,85,000',
#  '₹2,94,000',
#  '₹3,18,000',
#  '',
#  '₹2,77,600',
#  '',
#  '₹2,29,000',
#  '',
#  '₹6,52,000',
#  '₹7,17,000',
#  '₹4,57,000',
#  '₹3,11,000',
#  '₹4,78,000',
#  '₹4,09,000',
#  '',
#  '₹2,65,000',
#  '₹7,65,000',
#  '₹1,88,000',
#  '₹4,96,000',
#  '',
#  '₹4,98,000',
#  '₹2,88,000',
#  '',
#  '₹6,86,000',
#  '',
#  '₹3,64,000',
#  '₹4,04,000',
#  '₹7,13,000',
#  '₹7,38,000',
#  '',
#  '',
#  '₹2,51,000',
# ...

# %%
len(Price)
# Out:
# 1239

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (1239, 1239, 1239, 1239, 1239, 1239, 1239, 1239, 1239)

# %%
Car2=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})

# %%
Car2
# Out:
#         Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0         KIA  SELTOS                2020         5,999 km  Petrol
# 1         KIA  SELTOS                2020         9,417 km  Petrol
# 2     Hyundai   Grand                2019        19,964 km  Petrol
# 3      Maruti    Alto                2011        12,030 km  Petrol
# 4     Hyundai   Grand                2019        20,969 km  Petrol
# ...       ...     ...                 ...              ...     ...
# 1234  Hyundai   Grand                2016        24,035 km  Petrol
# 1235    Honda    City                2019        25,276 km  Petrol
# 1236   Maruti    Ritz                2010        44,527 km  Petrol
# 1237  Hyundai     NEW                2019        13,258 km  Petrol
# 1238  Hyundai   Verna                2021        18,670 km  Diesel
#
#      No. of Owner Variant   Location       Price
# 0       1st Owner    GTX+  New Delhi  ₹17,22,000
# 1       1st Owner     GTX  New Delhi  ₹16,81,000
# ...

# %%
Car2.to_csv('Car2_data.csv')

# %%
driver.close()

# %% [markdown]
# # Chapter:2 Mumbai

# %%
# Importing Chromedriver
driver=webdriver.Chrome(r'"C:\Users\amits\Desktop\chromedriver_win32\chromedriver.exe"')

# %%
url='https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001'
driver.get(url)

# %%
Manufacturing_year =[]
years=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    
    for i in years:
        
        Manufacturing_year.append(i.text.split()[0])
        

except NoSuchElementException:
    
    Manufacturing_year.append('Not Present')
    
Manufacturing_year
# Out:
# ['2011',
#  '2015',
#  '2014',
#  '2016',
#  '2020',
#  '2020',
#  '2017',
#  '2012',
#  '2018',
#  '2013',
#  '2018',
#  '2013',
#  '2018',
#  '2015',
#  '2014',
#  '2019',
#  '2015',
#  '2013',
#  '2012',
#  '2017',
#  '2015',
#  '2016',
#  '2021',
#  '2011',
#  '2016',
#  '2016',
#  '2017',
#  '2018',
#  '2015',
#  '2018',
#  '2014',
#  '2013',
#  '2018',
#  '2020',
#  '2015',
#  '2012',
#  '2012',
#  '2011',
#  '2017',
#  '2015',
#  '2016',
#  '2017',
#  '2019',
#  '2018',
#  '2020',
#  '2014',
#  '2022',
#  '2012',
#  '2014',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2013',
#  '2013',
#  '2012',
#  '2014',
#  '2019',
#  '2015',
#  '2016',
#  '2016',
#  '2015',
#  '2019',
#  '2015',
#  '2017',
#  '2017',
#  '2021',
#  '2017',
#  '2020',
#  '2016',
#  '2016',
#  '2019',
#  '2017',
#  '2011',
#  '2016',
#  '2017',
#  '2016',
#  '2015',
#  '2019',
#  '2018',
#  '2019',
#  '2012',
#  '2016',
#  '2020',
#  '2014',
#  '2016',
#  '2017',
#  '2016',
#  '2018',
# ...

# %%
Brands=[]
brand=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    for i in brand:
        Brands.append(i.text.split()[1])
except NoSuchElementException:
    Brands.append('Not Present')
    
Brands
# Out:
# ['Maruti',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Renault',
#  'Tata',
#  'Maruti',
#  'Skoda',
#  'Datsun',
#  'Volkswagen',
#  'Maruti',
#  'Maruti',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Volkswagen',
#  'Maruti',
#  'Renault',
#  'Maruti',
#  'Honda',
#  'Maruti',
#  'Hyundai',
#  'Mahindra',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Maruti',
#  'Maruti',
#  'Volkswagen',
#  'Maruti',
#  'Maruti',
#  'Maruti',
#  'Maruti',
#  'Mercedes',
#  'Maruti',
#  'Maruti',
#  'Volkswagen',
#  'Jeep',
#  'Mahindra',
#  'Honda',
#  'Tata',
#  'Hyundai',
#  'KIA',
#  'Honda',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Tata',
#  'Hyundai',
#  'Renault',
#  'Maruti',
#  'Honda',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Renault',
#  'Maruti',
#  'Hyundai',
#  'Datsun',
#  'Skoda',
#  'Hyundai',
#  'Volkswagen',
#  'Tata',
#  'Toyota',
#  'Renault',
#  'Maruti',
#  'Maruti',
#  'Ford',
#  'Jeep',
#  'Maruti',
# ...

# %%
Model=[]
models=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    for i in models:
        Model.append(i.text.split()[2])
except NoSuchElementException:
    Model.append('Not Present')
    
Model
# Out:
# ['Swift',
#  'Ertiga',
#  'Swift',
#  'i20',
#  'Kwid',
#  'Tiago',
#  'Ertiga',
#  'Rapid',
#  'Redi',
#  'Polo',
#  'Dzire',
#  'Wagon',
#  'Kwid',
#  'Grand',
#  'i20',
#  'Alto',
#  'i10',
#  'Alto',
#  'Swift',
#  'Ameo',
#  'Alto',
#  'Kwid',
#  'S',
#  'Jazz',
#  'Ciaz',
#  'Elite',
#  'TUV300',
#  'Verna',
#  'Celerio',
#  'Baleno',
#  'Wagon',
#  'Wagon',
#  'Polo',
#  'S',
#  'Celerio',
#  'Swift',
#  'Swift',
#  'Benz',
#  'Wagon',
#  'Swift',
#  'Vento',
#  'Compass',
#  'XUV',
#  'Amaze',
#  'NEXON',
#  'Grand',
#  'CARENS',
#  'City',
#  'Wagon',
#  'Baleno',
#  'Verna',
#  'Baleno',
#  'Tiago',
#  'Creta',
#  'Duster',
#  'Ertiga',
#  'Brio',
#  'i20',
#  'VENUE',
#  'Swift',
#  'Kwid',
#  'Baleno',
#  'Creta',
#  'Redi',
#  'Rapid',
#  'Verna',
#  'Ameo',
#  'TIGOR',
#  'Etios',
#  'Kwid',
#  'Ciaz',
#  'Swift',
#  'FREESTYLE',
#  'Compass',
#  'Wagon',
#  'Ciaz',
#  'Ameo',
#  'Ciaz',
#  'S',
#  'Polo',
#  'Tiago',
#  'Swift',
#  'Swift',
#  'Vento',
#  'Rapid',
# ...

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"cvakB")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['VDI',
#  'ZXI',
#  'ZXI',
#  '1.2',
#  '1.0',
#  'XT',
#  'VXI',
#  'ELEGANCE',
#  'S',
#  'HIGHLINE1.2L',
#  'VXI',
#  'VXI',
#  'RXT',
#  'SPORTZ',
#  'SPORTZ',
#  'VXI',
#  'SPORTZ',
#  'LXI',
#  'VXI',
#  'COMFORTLINE',
#  'LXI',
#  'RXT',
#  'LXI',
#  '1.2',
#  'ZDI',
#  'ASTA',
#  'T8',
#  '1.6',
#  'VXI',
#  'ALPHA',
#  'LXI',
#  'LXI',
#  'HIGH',
#  'VXI',
#  'ZXI',
#  'ZXI',
#  'VDI',
#  'E',
#  'LXI',
#  'VXI',
#  'HIGHLINE',
#  '2.0',
#  '1.5',
#  '1.2',
#  'XMA',
#  'SPORTZ',
#  'PRESTIGE',
#  'CORPORATE',
#  'LXI',
#  'ZETA',
#  '1.6',
#  'ALPHA',
#  'XE',
#  '1.6',
#  '85',
#  'VXI',
#  '1.2',
#  'SPORTZ',
#  'S',
#  'VXI',
#  '1.0',
#  'SIGMA',
#  '1.6',
#  '1.0',
#  'AMBITION',
#  'FLUIDIC',
#  'COMFORTLINE',
#  'XM',
#  'D',
#  'CLIMBER',
#  'ZDI',
#  'VDI',
#  'TITANIUM',
#  '2.0',
#  'LXI',
#  'VDI+',
#  'HIGHLINE',
#  'ZXI',
#  'ZETA',
#  'COMFORTLINE',
#  'XZA',
#  'ZXI',
#  'ZXI',
#  'HIGHLINE',
#  '1.6',
#  'GT',
#  'XT',
#  '3.2l',
#  'ZXI+',
#  'Magna',
# ...

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['76,277 km',
#  '75,586 km',
#  '65,693 km',
#  '13,751 km',
#  '8,356 km',
#  '9,893 km',
#  '78,587 km',
#  '79,069 km',
#  '16,660 km',
#  '63,030 km',
#  '22,231 km',
#  '30,760 km',
#  '64,049 km',
#  '64,218 km',
#  '42,730 km',
#  '14,829 km',
#  '50,979 km',
#  '22,138 km',
#  '87,736 km',
#  '93,990 km',
#  '70,614 km',
#  '47,587 km',
#  '32,020 km',
#  '59,591 km',
#  '77,273 km',
#  '76,293 km',
#  '70,203 km',
#  '49,459 km',
#  '37,749 km',
#  '73,047 km',
#  '33,071 km',
#  '39,044 km',
#  '32,263 km',
#  '41,047 km',
#  '20,240 km',
#  '41,890 km',
#  '55,416 km',
#  '78,206 km',
#  '87,260 km',
#  '10,468 km',
#  '62,215 km',
#  '29,875 km',
#  '73,403 km',
#  '67,419 km',
#  '46,116 km',
#  '41,503 km',
#  '1,574 km',
#  '69,898 km',
#  '71,296 km',
#  '4,560 km',
#  '60,877 km',
#  '36,179 km',
#  '17,904 km',
#  '48,030 km',
#  '65,705 km',
#  '33,557 km',
#  '36,743 km',
#  '71,429 km',
#  '15,371 km',
#  '10,155 km',
#  '22,233 km',
#  '29,592 km',
# ...

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'CNG',
#  'CNG',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'CNG',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹3,25,000',
#  '₹6,35,000',
#  '₹4,58,000',
#  '₹5,56,000',
#  '₹5,40,000',
#  '₹5,54,000',
#  '₹7,75,000',
#  '₹3,41,000',
#  '₹2,48,000',
#  '₹3,43,000',
#  '₹6,37,000',
#  '₹3,06,000',
#  '₹3,20,000',
#  '₹4,02,000',
#  '₹4,30,000',
#  '₹4,59,000',
#  '₹3,23,000',
#  '₹2,25,000',
#  '₹3,87,000',
#  '₹4,40,000',
#  '₹2,63,000',
#  '₹2,57,000',
#  '₹5,51,000',
#  '₹2,41,000',
#  '₹6,18,000',
#  '₹6,02,000',
#  '₹7,90,000',
#  '₹8,62,000',
#  '₹3,78,000',
#  '₹7,02,000',
#  '₹3,72,000',
#  '₹3,16,500',
#  '₹5,73,000',
#  '₹5,28,000',
#  '₹3,79,000',
#  '₹4,18,000',
#  '₹4,02,000',
#  '₹9,45,000',
#  '₹3,83,000',
#  '₹5,03,000',
#  '₹5,62,000',
#  '₹11,16,000',
#  '₹8,50,000',
#  '₹6,42,000',
#  '₹8,21,000',
#  '₹3,87,000',
#  '₹15,15,000',
#  '₹3,66,000',
#  '₹3,72,000',
#  '₹6,75,000',
#  '₹8,46,000',
#  '₹7,13,000',
#  '₹4,21,000',
#  '₹8,08,000',
#  '₹4,48,000',
#  '₹5,43,000',
#  '₹2,78,000',
#  '₹3,90,000',
#  '₹7,61,000',
#  '₹5,21,000',
#  '₹3,12,000',
#  '₹5,00,000',
# ...

# %%
location=['Mumbai']
Location=location*685
len(Location)
# Out:
# 685

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (685, 685, 685, 685, 685, 685, 685, 685, 685)

# %%
Car2=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})

# %%
Car2.to_csv('Car3_data.csv')

# %% [markdown]
# #   Chapter:3 Bangalore

# %%
url='https://www.cars24.com/buy-used-car?sort=P&storeCityId=4709&pinId=560001'
driver.get(url)

# %%
Manufacturing_year =[]
years=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    
    for i in years:
        
        Manufacturing_year.append(i.text.split()[0])
        

except NoSuchElementException:
    
    Manufacturing_year.append('Not Present')
    
Manufacturing_year
# Out:
# ['2019',
#  '2011',
#  '2016',
#  '2011',
#  '2017',
#  '2009',
#  '2018',
#  '2013',
#  '2015',
#  '2015',
#  '2022',
#  '2013',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2022',
#  '2018',
#  '2015',
#  '2015',
#  '2021',
#  '2010',
#  '2016',
#  '2017',
#  '2020',
#  '2015',
#  '2021',
#  '2012',
#  '2017',
#  '2016',
#  '2022',
#  '2022',
#  '2017',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2015',
#  '2015',
#  '2014',
#  '2016',
#  '2013',
#  '2014',
#  '2016',
#  '2019',
#  '2014',
#  '2019',
#  '2014',
#  '2015',
#  '2020',
#  '2019',
#  '2015',
#  '2020',
#  '2017',
#  '2019',
#  '2017',
#  '2014',
#  '2017',
#  '2020',
#  '2016',
#  '2013',
#  '2017',
#  '2011',
#  '2021',
#  '2014',
#  '2018',
#  '2021',
#  '2017',
#  '2020',
#  '2019',
#  '2015',
#  '2016',
#  '2022',
#  '2013',
#  '2010',
#  '2017',
#  '2019',
#  '2021',
#  '2012',
#  '2015',
#  '2010',
#  '2014',
#  '2017',
#  '2016',
#  '2021',
#  '2018',
#  '2015',
#  '2018',
#  '2021',
#  '2017',
# ...

# %%
Brands=[]
brand=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    for i in brand:
        Brands.append(i.text.split()[1])
except NoSuchElementException:
    Brands.append('Not Present')
    
Brands
# Out:
# ['Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Renault',
#  'Skoda',
#  'Hyundai',
#  'Renault',
#  'Tata',
#  'Hyundai',
#  'Ford',
#  'Renault',
#  'Mahindra',
#  'Renault',
#  'Nissan',
#  'Tata',
#  'Mahindra',
#  'Honda',
#  'Maruti',
#  'Maruti',
#  'Honda',
#  'Renault',
#  'Maruti',
#  'Datsun',
#  'Tata',
#  'Maruti',
#  'Hyundai',
#  'Volkswagen',
#  'Skoda',
#  'Skoda',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'Datsun',
#  'Volkswagen',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'KIA',
#  'Honda',
#  'KIA',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'KIA',
#  'Hyundai',
#  'Honda',
#  'Hyundai',
#  'Hyundai',
#  'Jeep',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Mahindra',
#  'Toyota',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'KIA',
#  'Honda',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Tata',
#  'Hyundai',
#  'Honda',
# ...

# %%
Model=[]
models=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    for i in models:
        Model.append(i.text.split()[2])
except NoSuchElementException:
    Model.append('Not Present')
    
Model
# Out:
# ['VENUE',
#  'i20',
#  'Ertiga',
#  'i20',
#  'Creta',
#  'Swift',
#  'Kwid',
#  'Rapid',
#  'Eon',
#  'Kwid',
#  'Tiago',
#  'i10',
#  'Ecosport',
#  'Duster',
#  'KUV',
#  'Duster',
#  'MAGNITE',
#  'Tiago',
#  'XUV500',
#  'Amaze',
#  'XL6',
#  'Alto',
#  'Amaze',
#  'Duster',
#  'New',
#  'Go',
#  'Safari',
#  'Ertiga',
#  'Elite',
#  'Ameo',
#  'SLAVIA',
#  'SLAVIA',
#  'Creta',
#  'Elite',
#  'Xcent',
#  'Duster',
#  'Elite',
#  'Elite',
#  'Go',
#  'Polo',
#  'Vitara',
#  'Eon',
#  'Celerio',
#  'Swift',
#  'SELTOS',
#  'City',
#  'SELTOS',
#  'Swift',
#  'Grand',
#  'AURA',
#  'SELTOS',
#  'Elite',
#  'City',
#  'Elite',
#  'NEW',
#  'Compass',
#  'i10',
#  'IGNIS',
#  'GRAND',
#  'i10',
#  'Verna',
#  'Kuv100',
#  'Etios',
#  'Kiger',
#  'Verna',
#  'Elite',
#  'SONET',
#  'WR-V',
#  'VENUE',
#  'Elite',
#  'Ciaz',
#  'i20',
#  'PUNCH',
#  'i20',
#  'City',
#  'Dzire',
#  'Creta',
#  'HECTOR',
#  'i20',
#  'Swift',
#  'i10',
#  'Swift',
#  'Ciaz',
#  'i10',
#  'VENUE',
# ...

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"cvakB")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['1.0',
#  'ASTA',
#  'VXI',
#  'SPORTZ',
#  'SX',
#  'VDI',
#  'CLIMBER',
#  '1.6',
#  'MAGNA',
#  'RXL',
#  'XZA+',
#  'ERA',
#  '1.5',
#  'RXS',
#  'K8',
#  'RXZ',
#  'XL',
#  'XZA',
#  'W6',
#  '1.2',
#  'ZETA',
#  'LXI',
#  '1.2L',
#  'RXS',
#  'ZXI',
#  'T(O)',
#  'XZ+',
#  'VDI',
#  'SPORTZ',
#  'TRENDLINE',
#  'STYLE',
#  'STYLE',
#  'SX',
#  'MAGNA',
#  'S',
#  '85',
#  'SPORTZ',
#  'MAGNA',
#  'T',
#  'HIGHLINE1.2L',
#  'ZDI',
#  'D-LITE+',
#  'VXI',
#  'LDI',
#  'GTX',
#  '1.5L',
#  'GTX+',
#  'VXI',
#  'MAGNA',
#  'S',
#  'HTK',
#  'MAGNA',
#  'VX',
#  'SPORTZ',
#  '1.1',
#  '2.0',
#  'SPORTZ',
#  'SIGMA',
#  'CORPRATE',
#  'MAGNA',
#  'FLUIDIC',
#  'K4',
#  'V',
#  'RXZ',
#  'FLUIDIC',
#  'SPORTZ',
#  'HTK+',
#  '1.5',
#  'S',
#  '1.2',
#  'ZXI',
#  '1.2',
#  'ACCOMPLISHED',
#  'ASTA',
#  'V',
#  'ZXI',
#  'SX',
#  'SMART',
#  'ASTA',
#  'ZXI',
#  'SPORTZ',
#  'ZXI',
#  '1.4',
#  'SPORTZ',
#  'S',
#  'SX',
#  '1.5',
#  'V',
#  'RXZ',
#  'XZ',
#  '1.2',
#  '1.2',
# ...

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['43,503 km',
#  '89,471 km',
#  '99,205 km',
#  '50,161 km',
#  '42,790 km',
#  '69,579 km',
#  '16,164 km',
#  '77,938 km',
#  '80,453 km',
#  '39,096 km',
#  '1,888 km',
#  '52,840 km',
#  '30,802 km',
#  '39,639 km',
#  '30,026 km',
#  '60,965 km',
#  '3,386 km',
#  '40,386 km',
#  '36,489 km',
#  '91,489 km',
#  '15,082 km',
#  '63,805 km',
#  '58,593 km',
#  '47,127 km',
#  '1,385 km',
#  '39,169 km',
#  '56,710 km',
#  '98,413 km',
#  '33,269 km',
#  '28,444 km',
#  '22,496 km',
#  '6,817 km',
#  '54,362 km',
#  '43,017 km',
#  '65,774 km',
#  '67,691 km',
#  '82,387 km',
#  '41,831 km',
#  '32,495 km',
#  '61,356 km',
#  '67,985 km',
#  '49,215 km',
#  '35,571 km',
#  '29,876 km',
#  '30,513 km',
#  '72,229 km',
#  '35,357 km',
#  '33,488 km',
#  '20,854 km',
#  '42,548 km',
#  '14,562 km',
#  '53,172 km',
#  '19,748 km',
#  '71,034 km',
#  '30,844 km',
#  '67,850 km',
#  '89,433 km',
#  '39,955 km',
#  '41,898 km',
#  '47,265 km',
#  '72,139 km',
#  '22,895 km',
# ...

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['',
#  '₹3,65,000',
#  '₹6,93,000',
#  '₹3,82,000',
#  '',
#  '₹3,43,000',
#  '₹4,84,000',
#  '₹5,00,000',
#  '₹3,06,000',
#  '₹3,04,000',
#  '',
#  '₹2,95,000',
#  '',
#  '',
#  '₹5,94,000',
#  '',
#  '₹7,43,000',
#  '₹5,86,000',
#  '',
#  '₹4,05,000',
#  '',
#  '₹1,80,000',
#  '₹5,07,000',
#  '',
#  '₹6,05,000',
#  '₹2,94,000',
#  '',
#  '₹6,77,000',
#  '₹6,41,000',
#  '₹5,28,000',
#  '',
#  '',
#  '',
#  '₹5,42,000',
#  '₹4,56,000',
#  '₹6,76,000',
#  '₹5,24,000',
#  '₹5,80,000',
#  '₹2,73,000',
#  '₹5,90,000',
#  '₹7,56,000',
#  '₹2,51,000',
#  '₹3,94,000',
#  '₹5,78,000',
#  '',
#  '₹6,31,000',
#  '',
#  '₹5,36,000',
#  '₹4,22,000',
#  '₹6,44,000',
#  '',
#  '₹5,51,000',
#  '',
#  '₹6,12,000',
#  '₹4,70,000',
#  '',
#  '₹3,16,000',
#  '₹4,63,500',
#  '₹6,66,000',
#  '₹4,08,000',
#  '₹5,04,000',
#  '₹4,58,000',
#  '₹3,71,000',
#  '',
#  '₹6,61,000',
#  '₹6,56,000',
#  '',
#  '₹7,96,000',
#  '',
#  '',
#  '₹6,58,000',
#  '₹5,91,400',
#  '',
#  '₹5,06,000',
#  '₹3,93,000',
# ...

# %%
location=['Bangalore']
Location=location*1226
len(Location)
# Out:
# 1226

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (1226, 1226, 1226, 1226, 1226, 1226, 1226, 1226, 1226)

# %%
Car4=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})

# %%
Car4.to_csv('Car4_data.csv')

# %%
driver.close()

# %% [markdown]
# # Chapter: 4 Hyderabaad

# %%
url='https://www.cars24.com/buy-used-car?sort=P&storeCityId=3686&pinId=500001'
driver.get(url)

# %%
Manufacturing_year =[]
years=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    
    for i in years:
        
        Manufacturing_year.append(i.text.split()[0])
        

except NoSuchElementException:
    
    Manufacturing_year.append('Not Present')
    
Manufacturing_year
# Out:
# ['2017',
#  '2011',
#  '2014',
#  '2017',
#  '2016',
#  '2016',
#  '2020',
#  '2020',
#  '2020',
#  '2017',
#  '2017',
#  '2016',
#  '2021',
#  '2018',
#  '2012',
#  '2019',
#  '2018',
#  '2018',
#  '2017',
#  '2019',
#  '2017',
#  '2016',
#  '2021',
#  '2018',
#  '2020',
#  '2017',
#  '2018',
#  '2015',
#  '2010',
#  '2018',
#  '2011',
#  '2018',
#  '2019',
#  '2017',
#  '2020',
#  '2017',
#  '2016',
#  '2020',
#  '2014',
#  '2016',
#  '2022',
#  '2014',
#  '2020',
#  '2017',
#  '2022',
#  '2022',
#  '2017',
#  '2019',
#  '2019',
#  '2017',
#  '2021',
#  '2021',
#  '2015',
#  '2017',
#  '2019',
#  '2018',
#  '2011',
#  '2012',
#  '2016',
#  '2019',
#  '2015',
#  '2014',
#  '2016',
#  '2016',
#  '2019',
#  '2019',
#  '2014',
#  '2018',
#  '2017',
#  '2015',
#  '2014',
#  '2017',
#  '2014',
#  '2017',
#  '2021',
#  '2017',
#  '2015',
#  '2019',
#  '2020',
#  '2014',
#  '2013',
#  '2013',
#  '2018',
#  '2019',
#  '2019',
#  '2017',
#  '2015',
#  '2017',
#  '2013',
#  '2017',
# ...

# %%
len(Manufacturing_year)
# Out:
# 555

# %%
Brands=[]
brand=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    for i in brand:
        Brands.append(i.text.split()[1])
except NoSuchElementException:
    Brands.append('Not Present')
    
Brands
# Out:
# ['Maruti',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Renault',
#  'Maruti',
#  'Tata',
#  'Renault',
#  'Renault',
#  'Maruti',
#  'Hyundai',
#  'Renault',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Renault',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Volkswagen',
#  'Datsun',
#  'Maruti',
#  'Skoda',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Maruti',
#  'Volkswagen',
#  'Maruti',
#  'Maruti',
#  'Toyota',
#  'Honda',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Skoda',
#  'Hyundai',
#  'Maruti',
#  'Volkswagen',
#  'Maruti',
#  'Mahindra',
#  'Nissan',
#  'MG',
#  'Renault',
#  'Maruti',
#  'Nissan',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Tata',
#  'MG',
#  'Hyundai',
#  'Hyundai',
#  'Volkswagen',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Honda',
#  'Volkswagen',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Maruti',
#  'Ford',
#  'Hyundai',
#  'Maruti',
#  'Volkswagen',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Skoda',
#  'Hyundai',
#  'Ford',
# ...

# %%
Model=[]
models=driver.find_elements(By.CLASS_NAME,"_3FpCg")
try:
    for i in models:
        Model.append(i.text.split()[2])
except NoSuchElementException:
    Model.append('Not Present')
    
Model
# Out:
# ['Baleno',
#  'Alto',
#  'Xcent',
#  'Dzire',
#  'Kwid',
#  'Alto',
#  'Tiago',
#  'Kwid',
#  'Kwid',
#  'Eeco',
#  'Elite',
#  'Kwid',
#  'New',
#  'Elite',
#  'Swift',
#  'Kwid',
#  'Grand',
#  'Grand',
#  'Elite',
#  'Polo',
#  'Redi',
#  'Baleno',
#  'Rapid',
#  'Eon',
#  'Swift',
#  'Swift',
#  'Vitara',
#  'Polo',
#  'Alto',
#  'Ciaz',
#  'Etios',
#  'Jazz',
#  'Elite',
#  'S',
#  'S',
#  'Rapid',
#  'Creta',
#  'Swift',
#  'Polo',
#  'Celerio',
#  'XUV',
#  'Terrano',
#  'HECTOR',
#  'Duster',
#  'Dzire',
#  'MAGNITE',
#  'Elite',
#  'S',
#  'Eon',
#  'i20',
#  'Tiago',
#  'HECTOR',
#  'Grand',
#  'Elite',
#  'Polo',
#  'Elite',
#  'i20',
#  'Swift',
#  'Jazz',
#  'Polo',
#  'Alto',
#  'Xcent',
#  'Elite',
#  'Alto',
#  'FREESTYLE',
#  'Verna',
#  'Celerio',
#  'Vento',
#  'Ciaz',
#  'Wagon',
#  'i20',
#  'Rapid',
#  'Grand',
#  'Ecosport',
#  'Baleno',
#  'Eon',
#  'Grand',
#  'Vitara',
#  'HECTOR',
#  'Micra',
#  'i10',
#  'City',
#  'Rapid',
#  'IGNIS',
#  'Baleno',
# ...

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"cvakB")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['SIGMA',
#  'VXI',
#  'S',
#  'ZDI',
#  'RXT',
#  'VXI',
#  'XZ+',
#  '1.0',
#  'RXT',
#  '5',
#  'SPORTZ',
#  '1.0',
#  'LXI',
#  'ASTA',
#  'VXI',
#  'RXL',
#  'ASTA',
#  'ASTA',
#  'ASTA',
#  'Trendline',
#  'T',
#  'DELTA',
#  'ACTIVE',
#  'MAGNA',
#  'VXI',
#  'VDI',
#  'ZDI',
#  'HIGHLINE1.2L',
#  'LXI',
#  'VDI+',
#  'G',
#  '1.2L',
#  'MAGNA+',
#  'ZETA',
#  'VXI',
#  'STYLE',
#  '1.6',
#  'VXI',
#  'COMFORTLINE',
#  'ZXI',
#  '1.2',
#  'XV',
#  'SHARP',
#  'RXZ',
#  'ZXI',
#  'XV',
#  'SPORTZ',
#  'ZETA',
#  'MAGNA',
#  '1.2',
#  'XT',
#  'SHINE',
#  'ASTA',
#  'ASTA',
#  'COMFORTLINE',
#  'Magna',
#  'MAGNA',
#  'ZXI',
#  '1.2',
#  'Trendline',
#  'LXI',
#  'SX',
#  'ASTA',
#  'VXI',
#  'TITANIUM',
#  '1.4',
#  'VXI',
#  'HIGHLINE',
#  'SIGMA',
#  'VXI',
#  'SPORTZ',
#  '1.6',
#  'ASTA',
#  '1.5TITANIUM',
#  'DELTA',
#  'MAGNA',
#  'SPORTZ',
#  'ZDI',
#  'SMART',
#  'XV',
#  'MAGNA',
#  'S',
#  '1.5',
#  'ZETA',
#  'ZETA',
#  '1.0',
#  'SPORTZ',
#  'GT',
#  'MAGNA',
# ...

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['74,739 km',
#  '72,439 km',
#  '92,116 km',
#  '69,564 km',
#  '43,240 km',
#  '68,686 km',
#  '82,009 km',
#  '43,009 km',
#  '62,021 km',
#  '86,826 km',
#  '87,312 km',
#  '49,214 km',
#  '17,969 km',
#  '59,188 km',
#  '99,553 km',
#  '39,111 km',
#  '35,485 km',
#  '44,212 km',
#  '94,366 km',
#  '60,076 km',
#  '41,744 km',
#  '48,758 km',
#  '40,819 km',
#  '58,380 km',
#  '24,368 km',
#  '68,816 km',
#  '93,509 km',
#  '40,051 km',
#  '47,633 km',
#  '98,020 km',
#  '78,154 km',
#  '26,572 km',
#  '27,441 km',
#  '59,548 km',
#  '75,258 km',
#  '91,707 km',
#  '96,615 km',
#  '60,933 km',
#  '88,524 km',
#  '51,038 km',
#  '13,194 km',
#  '90,968 km',
#  '69,338 km',
#  '69,982 km',
#  '5,748 km',
#  '3,391 km',
#  '66,077 km',
#  '86,194 km',
#  '36,667 km',
#  '32,305 km',
#  '42,978 km',
#  '18,780 km',
#  '40,876 km',
#  '37,470 km',
#  '36,003 km',
#  '86,375 km',
#  '93,357 km',
#  '53,287 km',
#  '99,600 km',
#  '34,901 km',
#  '69,091 km',
#  '63,811 km',
# ...

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['1st Owner',
#  '2nd Owner',
#  '3rd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹5,54,000',
#  '₹1,97,000',
#  '₹3,98,000',
#  '₹7,02,000',
#  '₹3,06,000',
#  '₹3,33,000',
#  '₹6,00,000',
#  '₹4,70,000',
#  '₹3,57,000',
#  '₹3,79,000',
#  '₹5,59,000',
#  '₹3,32,000',
#  '₹5,37,000',
#  '₹7,52,000',
#  '₹3,74,000',
#  '₹3,38,000',
#  '₹5,46,000',
#  '₹5,59,000',
#  '₹5,89,000',
#  '₹5,48,000',
#  '₹2,73,000',
#  '₹5,49,000',
#  '₹8,26,000',
#  '₹3,45,000',
#  '₹6,47,000',
#  '₹5,85,000',
#  '₹7,67,000',
#  '₹5,53,000',
#  '₹1,80,000',
#  '₹6,83,000',
#  '₹3,43,000',
#  '₹5,68,000',
#  '₹6,53,000',
#  '₹7,76,000',
#  '₹4,45,000',
#  '₹6,45,000',
#  '₹9,52,000',
#  '₹6,58,000',
#  '₹4,80,000',
#  '₹3,85,000',
#  '₹11,13,000',
#  '₹6,75,000',
#  '₹16,03,000',
#  '₹7,91,000',
#  '₹9,04,000',
#  '₹8,34,000',
#  '₹6,15,000',
#  '₹8,74,000',
#  '₹3,37,000',
#  '₹6,89,000',
#  '₹5,80,500',
#  '₹16,02,000',
#  '₹4,71,000',
#  '₹6,61,000',
#  '₹7,65,000',
#  '₹6,14,000',
#  '₹3,34,000',
#  '₹4,56,000',
#  '₹4,64,000',
#  '₹5,67,000',
#  '₹2,50,000',
#  '₹4,91,000',
# ...

# %%
location=['Hyderabaad']
Location=location*555
len(Location)
# Out:
# 555

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (555, 555, 555, 555, 555, 555, 555, 555, 555)

# %%
Car5=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})

# %%
Car5.to_csv('Car5_data.csv')

# %%
driver.close()

# %% [markdown]
# # Chapter: 5  (Kolkata)

# %%
url=('https://www.cars24.com/buy-used-car?sort=P&serveWarrantyCount=true&gaId=11487337.1675431892&storeCityId=777&pinId=700001')
driver.get(url)

# %%
Manufacturing_year =[]
years=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    
    for i in years:
        
        Manufacturing_year.append(i.text.split()[0])
        

except NoSuchElementException:
    
    Manufacturing_year.append('Not Present')
    
Manufacturing_year
# Out:
# ['2011',
#  '2015',
#  '2015',
#  '2010',
#  '2011',
#  '2016',
#  '2014',
#  '2013',
#  '2013',
#  '2014',
#  '2014',
#  '2021',
#  '2017',
#  '2014',
#  '2018',
#  '2014',
#  '2016',
#  '2019',
#  '2018',
#  '2020',
#  '2017',
#  '2019',
#  '2020',
#  '2012',
#  '2014',
#  '2014',
#  '2019',
#  '2018',
#  '2014',
#  '2018',
#  '2018',
#  '2018',
#  '2015',
#  '2017',
#  '2021',
#  '2020',
#  '2013',
#  '2015',
#  '2013',
#  '2018',
#  '2015',
#  '2019',
#  '2020',
#  '2018',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2015',
#  '2014',
#  '2018',
#  '2020',
#  '2015',
#  '2014',
#  '2018',
#  '2013',
#  '2012',
#  '2017',
#  '2014',
#  '2018',
#  '2019',
#  '2019',
#  '2022',
#  '2019',
#  '2020',
#  '2018',
#  '2020',
#  '2015',
#  '2015',
#  '2021',
#  '2015',
#  '2015',
#  '2014',
#  '2013',
#  '2017',
#  '2016',
#  '2018',
#  '2018',
#  '2015',
#  '2019',
#  '2016',
#  '2019',
#  '2018',
#  '2013',
#  '2013',
#  '2015',
#  '2017',
#  '2020',
#  '2015',
#  '2021',
# ...

# %%
Brands=[]
brand=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    for i in brand:
        Brands.append(i.text.split()[1])
except NoSuchElementException:
    Brands.append('Not Present')
    
Brands
# Out:
# ['Toyota',
#  'Maruti',
#  'HONDA',
#  'HYUNDAI',
#  'Hyundai',
#  'HYUNDAI',
#  'MARUTI',
#  'Maruti',
#  'MARUTI',
#  'Toyota',
#  'MARUTI',
#  'MAHINDRA',
#  'Renault',
#  'MARUTI',
#  'Hyundai',
#  'HYUNDAI',
#  'Maruti',
#  'MARUTI',
#  'MARUTI',
#  'MARUTI',
#  'Hyundai',
#  'KIA',
#  'MAHINDRA',
#  'Honda',
#  'Honda',
#  'HYUNDAI',
#  'RENAULT',
#  'MARUTI',
#  'Maruti',
#  'Volkswagen',
#  'Renault',
#  'HONDA',
#  'Hyundai',
#  'Honda',
#  'Maruti',
#  'Renault',
#  'MARUTI',
#  'MARUTI',
#  'Ford',
#  'MARUTI',
#  'Maruti',
#  'Maruti',
#  'Maruti',
#  'Honda',
#  'Maruti',
#  'VOLKSWAGEN',
#  'Maruti',
#  'HYUNDAI',
#  'MARUTI',
#  'HONDA',
#  'FORD',
#  'KIA',
#  'MARUTI',
#  'MARUTI',
#  'Maruti',
#  'Maruti',
#  'MARUTI',
#  'HONDA',
#  'MARUTI',
#  'MARUTI',
#  'Ford',
#  'MARUTI',
#  'RENAULT',
#  'DATSUN',
#  'Tata',
#  'HYUNDAI',
#  'Maruti',
#  'HYUNDAI',
#  'Maruti',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Ford',
#  'MARUTI',
#  'MARUTI',
#  'Hyundai',
# ...

# %%
Model=[]
models=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    for i in models:
        Model.append(i.text.split()[2])
except NoSuchElementException:
    Model.append('Not Present')
    
Model
# Out:
# ['Etios',
#  'Suzuki',
#  'CITY',
#  'I10',
#  'i10',
#  'CRETA',
#  'SUZUKI',
#  'Suzuki',
#  'SUZUKI',
#  'Etios',
#  'SUZUKI',
#  'XUV',
#  'Duster',
#  'SUZUKI',
#  'Verna',
#  'ELITE',
#  'Suzuki',
#  'SUZUKI',
#  'SUZUKI',
#  'SUZUKI',
#  'New',
#  'SELTOS',
#  'SCORPIO',
#  'City',
#  'City',
#  'I20',
#  'TRIBER',
#  'SUZUKI',
#  'Suzuki',
#  'Vento',
#  'Kwid',
#  'WR-V',
#  'Elite',
#  'City',
#  'Suzuki',
#  'Kwid',
#  'SUZUKI',
#  'SUZUKI',
#  'Ecosport',
#  'SUZUKI',
#  'Suzuki',
#  'Suzuki',
#  'Suzuki',
#  'City',
#  'Suzuki',
#  'VENTO',
#  'Suzuki',
#  'CRETA',
#  'SUZUKI',
#  'AMAZE',
#  'ECOSPORT',
#  'SELTOS',
#  'SUZUKI',
#  'SUZUKI',
#  'Suzuki',
#  'Suzuki',
#  'SUZUKI',
#  'WR-V',
#  'SUZUKI',
#  'ALTO',
#  'Ecosport',
#  'SUZUKI',
#  'Kiger',
#  'GO',
#  'NEXON',
#  'XCENT',
#  'Suzuki',
#  'ELITE',
#  'Suzuki',
#  'Suzuki',
#  'Grand',
#  'Suzuki',
#  'Ecosport',
#  'SUZUKI',
#  'SUZUKI',
#  'i20',
#  'Suzuki',
#  'ELITE',
#  'Suzuki',
#  'Creta',
# ...

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"_1hOnS")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['VManual',
#  'LXIManual',
#  '1.5L',
#  'MAGNA',
#  'ERA',
#  '1.6',
#  'LXIManual',
#  'VXIManual',
#  'LXIManual',
#  'CROSS',
#  'VXIManual',
#  '1.2',
#  '85',
#  'LXIManual',
#  '1.4',
#  'SPORTZ',
#  'ZDI',
#  'ZXIManual',
#  'VXIManual',
#  'ALPHA',
#  '2.0',
#  'GTK',
#  'S11Manual',
#  'CORPORATE',
#  'VX',
#  'SPORTZ',
#  '1.0',
#  'VXIManual',
#  'VXIManual',
#  'COMFORTLINE',
#  '1.0',
#  '1.5',
#  'ASTA',
#  'V',
#  'ZETA',
#  'CLIMBER',
#  'VXIManual',
#  'VXIManual',
#  '1.0',
#  'LXIManual',
#  'ALPHA',
#  'LXIManual',
#  'VXI',
#  'V',
#  'LXIManual',
#  '1.2',
#  'VXI',
#  '1.6',
#  'VXIManual',
#  '1.2',
#  '1.5',
#  '1.5',
#  'ZDI+',
#  'VXIManual',
#  'VXIManual',
#  'VXIManual',
#  'VXIManual',
#  '1.2',
#  'VXIManual',
#  'VXI',
#  '1.5',
#  'VXIManual',
#  'RXZ',
#  'T',
#  'XZA+',
#  'E',
#  'LXIManual',
#  'ASTA',
#  'ZXIManual',
#  'VXIManual',
#  'MAGNA',
#  'VXIManual',
#  '1.5',
#  'VXIManual',
#  'VDI',
#  '1.2',
#  'ZETA',
#  'Magna',
# ...

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['47,612 KM',
#  '5,650 KM',
#  '58,257 KM',
#  '76,641 KM',
#  '44,485 KM',
#  '57,359 KM',
#  '40,350 KM',
#  '73,569 KM',
#  '38,763 KM',
#  '59,338 KM',
#  '76,725 KM',
#  '15,778 KM',
#  '44,396 KM',
#  '35,965 KM',
#  '31,681 KM',
#  '62,542 KM',
#  '74,312 KM',
#  '8,087 KM',
#  '25,144 KM',
#  '6,403 KM',
#  '61,558 KM',
#  '25,489 KM',
#  '32,328 KM',
#  '81,247 KM',
#  '88,482 KM',
#  '53,277 KM',
#  '4,277 KM',
#  '27,567 KM',
#  '12,911 KM',
#  '10,666 KM',
#  '31,896 KM',
#  '98,117 KM',
#  '54,141 KM',
#  '10,050 KM',
#  '2,877 KM',
#  '33,019 KM',
#  '65,099 KM',
#  '11,364 KM',
#  '38,409 KM',
#  '70,180 KM',
#  '77,485 KM',
#  '32,399 KM',
#  '53,507 KM',
#  '31,838 KM',
#  '18,313 KM',
#  '63,374 KM',
#  '25,412 KM',
#  '39,813 KM',
#  '24,063 KM',
#  '31,001 KM',
#  '54,544 KM',
#  '67,429 KM',
#  '86,805 KM',
#  '40,481 KM',
#  '20,460 KM',
#  '76,780 KM',
#  '40,186 KM',
#  '32,844 KM',
#  '31,316 KM',
#  '44,200 KM',
#  '38,554 KM',
#  '46,283 KM',
# ...

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '2ND OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '3RD OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
# ...

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹2,71,000',
#  '₹2,48,000',
#  '₹4,66,000',
#  '₹1,79,000',
#  '₹1,87,000',
#  '₹6,52,000',
#  '₹1,92,000',
#  '₹2,66,000',
#  '₹1,97,000',
#  '₹3,61,000',
#  '₹3,90,000',
#  '₹7,12,000',
#  '₹5,11,000',
#  '₹2,01,000',
#  '₹6,51,000',
#  '₹4,02,000',
#  '₹5,91,000',
#  '₹6,25,000',
#  '₹5,41,000',
#  '₹7,50,000',
#  '₹7,64,000',
#  '₹10,88,000',
#  '₹15,64,000',
#  '₹3,26,000',
#  '₹5,29,000',
#  '₹3,40,000',
#  '₹5,63,000',
#  '₹5,43,000',
#  '₹4,60,000',
#  '₹6,15,000',
#  '₹3,15,000',
#  '₹5,62,000',
#  '₹4,51,000',
#  '₹6,42,000',
#  '₹7,00,000',
#  '₹4,65,000',
#  '₹3,29,000',
#  '₹3,61,000',
#  '₹4,46,000',
#  '₹2,77,000',
#  '₹4,39,000',
#  '₹3,39,000',
#  '₹3,75,000',
#  '₹7,31,000',
#  '₹2,97,000',
#  '₹6,30,000',
#  '₹5,30,700',
#  '₹7,78,000',
#  '₹3,51,000',
#  '₹3,62,000',
#  '₹6,49,000',
#  '₹14,20,000',
#  '₹4,47,000',
#  '₹3,10,000',
#  '₹6,01,000',
#  '₹2,67,000',
#  '₹3,26,000',
#  '₹7,06,000',
#  '₹3,30,000',
#  '₹3,59,000',
#  '₹7,83,000',
#  '₹5,36,000',
# ...

# %%
len(Price)
# Out:
# 219

# %%
location=['Kolkata']
Location=location*219
len(Location)
# Out:
# 219

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (219, 219, 219, 219, 219, 219, 219, 219, 219)

# %%
Car6=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})
Car6
# Out:
#        Brand   Model Manufacturing Year Driven Kilometer   Fuels No. of Owner  \
# 0     Toyota   Etios               2011        47,612 KM  PETROL    1ST OWNER
# 1     Maruti  Suzuki               2015         5,650 KM  PETROL    1ST OWNER
# 2      HONDA    CITY               2015        58,257 KM  PETROL    2ND OWNER
# 3    HYUNDAI     I10               2010        76,641 KM  PETROL    2ND OWNER
# 4    Hyundai     i10               2011        44,485 KM  PETROL    2ND OWNER
# ..       ...     ...                ...              ...     ...          ...
# 214   Maruti  Suzuki               2014        93,199 KM  PETROL    1ST OWNER
# 215   MARUTI  SUZUKI               2018        11,060 KM  PETROL    1ST OWNER
# 216  Hyundai   Elite               2018        40,897 KM  PETROL    1ST OWNER
# 217   Maruti  Suzuki               2020         8,246 KM  PETROL    1ST OWNER
# 218  Hyundai     i20               2015        72,727 KM  PETROL    1ST OWNER
#
# ...

# %%
Car6.to_csv('Car6_data.csv')

# %%
driver.close()

# %% [markdown]
# #  Chapter : 6 (Gurgaon)

# %%
url=('https://www.cars24.com/buy-used-car?sort=P&serveWarrantyCount=true&gaId=11487337.1675431892&storeCityId=5&pinId=122001')
driver.get(url)

# %%
Manufacturing_year =[]
years=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    
    for i in years:
        
        Manufacturing_year.append(i.text.split()[0])
        

except NoSuchElementException:
    
    Manufacturing_year.append('Not Present')
    
Manufacturing_year
# Out:
# ['2011',
#  '2019',
#  '2019',
#  '2012',
#  '2020',
#  '2021',
#  '2013',
#  '2013',
#  '2014',
#  '2013',
#  '2013',
#  '2019',
#  '2020',
#  '2014',
#  '2014',
#  '2011',
#  '2012',
#  '2014',
#  '2018',
#  '2011',
#  '2020',
#  '2019',
#  '2015',
#  '2010',
#  '2016',
#  '2009',
#  '2020',
#  '2014',
#  '2020',
#  '2021',
#  '2013',
#  '2014',
#  '2020',
#  '2021',
#  '2011',
#  '2014',
#  '2020',
#  '2021',
#  '2020',
#  '2012',
#  '2014',
#  '2021',
#  '2013',
#  '2019',
#  '2012',
#  '2018',
#  '2014',
#  '2022',
#  '2019',
#  '2020',
#  '2020',
#  '2014',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2018',
#  '2013',
#  '2020',
#  '2017',
#  '2015',
#  '2011',
#  '2022',
#  '2020',
#  '2020',
#  '2017',
#  '2014',
#  '2017',
#  '2016',
#  '2012',
#  '2021',
#  '2012',
#  '2016',
#  '2018',
#  '2021',
#  '2022',
#  '2017',
#  '2019',
#  '2020',
#  '2017',
#  '2013',
#  '2016',
#  '2019',
#  '2014',
#  '2014',
#  '2019',
#  '2015',
#  '2011',
#  '2019',
# ...

# %%
len(Manufacturing_year)
# Out:
# 1176

# %%
Brands=[]
brand=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    for i in brand:
        Brands.append(i.text.split()[1])
except NoSuchElementException:
    Brands.append('Not Present')
    
Brands
# Out:
# ['Honda',
#  'Jeep',
#  'Jeep',
#  'Honda',
#  'Skoda',
#  'Hyundai',
#  'Maruti',
#  'HYUNDAI',
#  'Hyundai',
#  'Honda',
#  'HONDA',
#  'HONDA',
#  'Toyota',
#  'HONDA',
#  'Hyundai',
#  'MARUTI',
#  'HONDA',
#  'Hyundai',
#  'Honda',
#  'Maruti',
#  'VOLKSWAGEN',
#  'HYUNDAI',
#  'Maruti',
#  'HYUNDAI',
#  'Renault',
#  'MARUTI',
#  'KIA',
#  'MARUTI',
#  'KIA',
#  'KIA',
#  'Maruti',
#  'MARUTI',
#  'KIA',
#  'Skoda',
#  'Maruti',
#  'MARUTI',
#  'KIA',
#  'KIA',
#  'Skoda',
#  'Maruti',
#  'Hyundai',
#  'TOYOTA',
#  'HYUNDAI',
#  'KIA',
#  'HONDA',
#  'Honda',
#  'Hyundai',
#  'KIA',
#  'Maruti',
#  'RENAULT',
#  'KIA',
#  'HONDA',
#  'KIA',
#  'MG',
#  'Renault',
#  'KIA',
#  'Maruti',
#  'HONDA',
#  'Honda',
#  'Skoda',
#  'Honda',
#  'HONDA',
#  'Hyundai',
#  'SKODA',
#  'Maruti',
#  'KIA',
#  'HONDA',
#  'Ford',
#  'Honda',
#  'FORD',
#  'Honda',
#  'Renault',
#  'Maruti',
#  'Honda',
#  'Renault',
#  'Honda',
#  'Renault',
#  'Honda',
#  'KIA',
#  'KIA',
#  'MARUTI',
# ...

# %%
Model=[]
models=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    for i in models:
        Model.append(i.text.split()[2])
except NoSuchElementException:
    Model.append('Not Present')
    
Model
# Out:
# ['City',
#  'Compass',
#  'Compass',
#  'Brio',
#  'Rapid',
#  'VENUE',
#  'Suzuki',
#  'I20',
#  'Grand',
#  'City',
#  'CITY',
#  'CITY',
#  'YARIS',
#  'CITY',
#  'Grand',
#  'SUZUKI',
#  'CITY',
#  'Grand',
#  'City',
#  'Swift',
#  'POLO',
#  'CRETA',
#  'Alto',
#  'I10',
#  'Kwid',
#  'SUZUKI',
#  'SELTOS',
#  'SUZUKI',
#  'SELTOS',
#  'SELTOS',
#  'Suzuki',
#  'SUZUKI',
#  'SONET',
#  'KUSHAQ',
#  'Suzuki',
#  'SUZUKI',
#  'SELTOS',
#  'SELTOS',
#  'Rapid',
#  'Suzuki',
#  'Grand',
#  'YARIS',
#  'I20',
#  'SELTOS',
#  'CITY',
#  'City',
#  'i20',
#  'CARENS',
#  'Suzuki',
#  'KWID',
#  'SELTOS',
#  'CITY',
#  'SELTOS',
#  'HECTOR',
#  'Kwid',
#  'SELTOS',
#  'Suzuki',
#  'CITY',
#  'Brio',
#  'Rapid',
#  'City',
#  'CITY',
#  'i10',
#  'KUSHAQ',
#  'Suzuki',
#  'SELTOS',
#  'CITY',
#  'Ecosport',
#  'City',
#  'ECOSPORT',
#  'Brio',
#  'Kwid',
#  'Suzuki',
#  'City',
#  'Kwid',
#  'City',
#  'Kwid',
#  'City',
#  'SELTOS',
#  'SONET',
#  'SUZUKI',
#  'Suzuki',
#  'Suzuki',
# ...

# %%
len(Model)
# Out:
# 1176

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"_1hOnS")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['S',
#  '1.4',
#  '2.0',
#  '1.2',
#  'ACTIVE',
#  'S',
#  'VXIManual',
#  'MAGNA',
#  'MAGNA',
#  'S',
#  '1.5',
#  'ZX',
#  'J',
#  'SV',
#  'ASTA',
#  'LXIManual',
#  '1.5L',
#  'ASTA',
#  'V',
#  'ZXIManual',
#  'COMFORTLINE',
#  '1.4',
#  'VXI',
#  'ERA',
#  '1.0',
#  'VXI',
#  'GTX+',
#  'LXIManual',
#  'GTX',
#  'HTX',
#  'VXIManual',
#  'VXIManual',
#  'GTX',
#  'STYLE',
#  'VXIManual',
#  'LXIManual',
#  'HTK',
#  'HTX',
#  '1.0',
#  'LXIManual',
#  'MAGNA',
#  'J',
#  'SPORTZ',
#  '1.5',
#  'S',
#  'V',
#  'SPORTZ',
#  'LUXURY',
#  'LXIManual',
#  'RXTManual',
#  'HTX',
#  '1.5L',
#  'GTX',
#  'SHARP',
#  '1.0',
#  'HTK',
#  'ZXI',
#  'V',
#  '1.2',
#  '1.0',
#  'V',
#  'SV',
#  'MAGNA',
#  'STYLE',
#  'VXIManual',
#  'GTX',
#  'V',
#  '1.5',
#  'V',
#  '1.5AMBIENTE',
#  '1.2',
#  'RXLManual',
#  'LXIManual',
#  'VX',
#  '1.0',
#  'V',
#  '1.0',
#  'V',
#  'HTK',
#  'GTX',
#  'VXIManual',
#  'VXIManual',
#  'DELTA',
#  'VXIManual',
#  'MAGNA',
#  'VX',
#  'SV',
#  'V',
# ...

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['52,408 KM',
#  '23,690 KM',
#  '47,136 KM',
#  '52,532 KM',
#  '18,953 KM',
#  '6,063 KM',
#  '61,753 KM',
#  '37,099 KM',
#  '25,771 KM',
#  '45,482 KM',
#  '32,933 KM',
#  '99,460 KM',
#  '9,572 KM',
#  '40,756 KM',
#  '57,770 KM',
#  '73,738 KM',
#  '40,745 KM',
#  '60,865 KM',
#  '49,089 KM',
#  '79,489 KM',
#  '22,311 KM',
#  '75,115 KM',
#  '45,436 KM',
#  '46,523 KM',
#  '16,545 KM',
#  '26,741 KM',
#  '6,003 KM',
#  '6,920 KM',
#  '9,417 KM',
#  '22,752 KM',
#  '68,674 KM',
#  '21,670 KM',
#  '12,461 KM',
#  '7,182 KM',
#  '82,915 KM',
#  '44,816 KM',
#  '49,350 KM',
#  '60,147 KM',
#  '10,713 KM',
#  '30,029 KM',
#  '62,001 KM',
#  '8,465 KM',
#  '56,159 KM',
#  '53,930 KM',
#  '45,073 KM',
#  '31,912 KM',
#  '59,025 KM',
#  '3,084 KM',
#  '1,994 KM',
#  '12,617 KM',
#  '10,678 KM',
#  '47,687 KM',
#  '18,469 KM',
#  '92,298 KM',
#  '10,509 KM',
#  '53,070 KM',
#  '1,413 KM',
#  '71,080 KM',
#  '91,780 KM',
#  '55,144 KM',
#  '58,982 KM',
#  '47,670 KM',
#  '32,648 KM',
# ...

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
# ...

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹3,16,000',
#  '₹18,79,000',
#  '₹16,67,000',
#  '₹2,47,000',
#  '₹8,85,000',
#  '₹8,74,000',
#  '₹2,82,000',
#  '₹3,94,000',
#  '₹4,30,000',
#  '₹5,22,000',
#  '₹4,76,000',
#  '₹9,25,000',
#  '₹8,91,000',
#  '₹5,51,000',
#  '₹4,09,000',
#  '₹2,70,000',
#  '₹4,01,000',
#  '₹4,10,000',
#  '₹8,81,000',
#  '₹3,10,000',
#  '₹6,53,000',
#  '₹8,90,000',
#  '₹3,16,000',
#  '₹1,68,000',
#  '₹2,69,000',
#  '₹2,01,000',
#  '₹16,89,000',
#  '₹2,72,000',
#  '₹16,73,000',
#  '₹14,07,000',
#  '₹2,64,000',
#  '₹2,78,000',
#  '₹13,39,000',
#  '₹17,01,000',
#  '₹2,52,000',
#  '₹2,46,000',
#  '₹14,42,000',
#  '₹14,18,000',
#  '₹10,87,000',
#  '₹2,29,000',
#  '₹3,56,000',
#  '₹10,18,000',
#  '₹3,82,000',
#  '₹17,12,000',
#  '₹4,66,000',
#  '₹9,02,000',
#  '₹4,49,000',
#  '₹17,42,000',
#  '₹5,66,000',
#  '₹4,43,000',
#  '₹13,58,000',
#  '₹6,86,000',
#  '₹16,91,000',
#  '₹13,96,000',
#  '₹4,78,000',
#  '₹10,55,000',
#  '₹7,04,000',
#  '₹7,82,000',
#  '₹2,98,000',
#  '₹9,54,000',
#  '₹7,95,000',
# ...

# %%
len(Price)
# Out:
# 1176

# %%
Location=[]
location=['Gurgaon']
Location=location*1176
len(Location)
# Out:
# 1176

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (1176, 1176, 1176, 1176, 1176, 1176, 1176, 1176, 1176)

# %%
Car5=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})
Car5
# Out:
#          Brand    Model Manufacturing Year Driven Kilometer   Fuels  \
# 0        Honda     City               2011        52,408 KM  PETROL
# 1         Jeep  Compass               2019        23,690 KM  PETROL
# 2         Jeep  Compass               2019        47,136 KM  DIESEL
# 3        Honda     Brio               2012        52,532 KM  PETROL
# 4        Skoda    Rapid               2020        18,953 KM  PETROL
# ...        ...      ...                ...              ...     ...
# 1171     HONDA    AMAZE               2019        20,700 KM  PETROL
# 1172    Maruti   Suzuki               2018        58,200 KM     CNG
# 1173  Mahindra     Thar               2022         1,102 KM  PETROL
# 1174   Renault     Kwid               2019        25,519 KM  PETROL
# 1175    MARUTI   SUZUKI               2019        68,219 KM  DIESEL
#
#      No. of Owner    Variant Location       Price
# 0       1ST OWNER          S  Gurgaon   ₹3,16,000
# ...

# %%
Car5.to_csv('Car5_data.csv')

# %% [markdown]
# # Concatinating All csv file In one csv file.

# %%
dfCar2=pd.read_csv("Car2_data.csv")
dfCar2
# Out:
#       Unnamed: 0    Brand   Model  Manufacturing Year Driven Kilometer  \
# 0              0      KIA  SELTOS                2020         5,999 km
# 1              1      KIA  SELTOS                2020         9,417 km
# 2              2  Hyundai   Grand                2019        19,964 km
# 3              3   Maruti    Alto                2011        12,030 km
# 4              4  Hyundai   Grand                2019        20,969 km
# ...          ...      ...     ...                 ...              ...
# 1234        1234  Hyundai   Grand                2016        24,035 km
# 1235        1235    Honda    City                2019        25,276 km
# 1236        1236   Maruti    Ritz                2010        44,527 km
# 1237        1237  Hyundai     NEW                2019        13,258 km
# 1238        1238  Hyundai   Verna                2021        18,670 km
#
#        Fuels No. of Owner Variant   Location       Price
# 0     Petrol    1st Owner    GTX+  New Delhi  ₹17,22,000
# ...

# %%
dfCar3=pd.read_csv("Car3_data.csv")
dfCar3
# Out:
#      Unnamed: 0    Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0             0   Maruti   Swift                2011        76,277 km  Diesel
# 1             1   Maruti  Ertiga                2015        75,586 km  Petrol
# 2             2   Maruti   Swift                2014        65,693 km  Petrol
# 3             3  Hyundai     i20                2016        13,751 km  Petrol
# 4             4  Renault    Kwid                2020         8,356 km  Petrol
# ..          ...      ...     ...                 ...              ...     ...
# 680         680  Hyundai   Grand                2015        31,857 km  Petrol
# 681         681  Hyundai     Eon                2014        30,721 km  Petrol
# 682         682   Maruti       A                2011        82,099 km  Petrol
# 683         683   Maruti   Wagon                2017        86,977 km     CNG
# 684         684  Hyundai     i20                2011        23,105 km  Petrol
#
# ...

# %%
dfCar4=pd.read_csv("Car4_data.csv")
dfCar4
# Out:
#       Unnamed: 0    Brand   Model  Manufacturing Year Driven Kilometer  \
# 0              0  Hyundai   VENUE                2019        43,503 km
# 1              1  Hyundai     i20                2011        89,471 km
# 2              2   Maruti  Ertiga                2016        99,205 km
# 3              3  Hyundai     i20                2011        50,161 km
# 4              4  Hyundai   Creta                2017        42,790 km
# ...          ...      ...     ...                 ...              ...
# 1221        1221  Hyundai   GRAND                2020        15,620 km
# 1222        1222    Honda    Brio                2014        17,054 km
# 1223        1223   Maruti   Swift                2021        10,975 km
# 1224        1224   Datsun      Go                2016        76,598 km
# 1225        1225  Hyundai   Verna                2011        81,911 km
#
#        Fuels No. of Owner  Variant   Location      Price
# 0     Petrol    1st Owner      1.0  Bangalore        NaN
# ...

# %%
dfCar5=pd.read_csv("Car5_data.csv")
dfCar5
# Out:
#       Unnamed: 0     Brand    Model  Manufacturing Year Driven Kilometer  \
# 0              0     Honda     City                2011        52,408 KM
# 1              1      Jeep  Compass                2019        23,690 KM
# 2              2      Jeep  Compass                2019        47,136 KM
# 3              3     Honda     Brio                2012        52,532 KM
# 4              4     Skoda    Rapid                2020        18,953 KM
# ...          ...       ...      ...                 ...              ...
# 1171        1171     HONDA    AMAZE                2019        20,700 KM
# 1172        1172    Maruti   Suzuki                2018        58,200 KM
# 1173        1173  Mahindra     Thar                2022         1,102 KM
# 1174        1174   Renault     Kwid                2019        25,519 KM
# 1175        1175    MARUTI   SUZUKI                2019        68,219 KM
#
#        Fuels No. of Owner    Variant Location       Price
# ...

# %%
dfCar6=pd.read_csv("Car6_data.csv")
dfCar6
# Out:
#      Unnamed: 0    Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0             0   Toyota   Etios                2011        47,612 KM  PETROL
# 1             1   Maruti  Suzuki                2015         5,650 KM  PETROL
# 2             2    HONDA    CITY                2015        58,257 KM  PETROL
# 3             3  HYUNDAI     I10                2010        76,641 KM  PETROL
# 4             4  Hyundai     i10                2011        44,485 KM  PETROL
# ..          ...      ...     ...                 ...              ...     ...
# 214         214   Maruti  Suzuki                2014        93,199 KM  PETROL
# 215         215   MARUTI  SUZUKI                2018        11,060 KM  PETROL
# 216         216  Hyundai   Elite                2018        40,897 KM  PETROL
# 217         217   Maruti  Suzuki                2020         8,246 KM  PETROL
# 218         218  Hyundai     i20                2015        72,727 KM  PETROL
#
# ...

# %%
DF=[dfCar2,dfCar3]
DF2_3=pd.concat(DF).reset_index(drop=True)
DF2_3
# Out:
#       Unnamed: 0    Brand   Model  Manufacturing Year Driven Kilometer  \
# 0              0      KIA  SELTOS                2020         5,999 km
# 1              1      KIA  SELTOS                2020         9,417 km
# 2              2  Hyundai   Grand                2019        19,964 km
# 3              3   Maruti    Alto                2011        12,030 km
# 4              4  Hyundai   Grand                2019        20,969 km
# ...          ...      ...     ...                 ...              ...
# 1919         680  Hyundai   Grand                2015        31,857 km
# 1920         681  Hyundai     Eon                2014        30,721 km
# 1921         682   Maruti       A                2011        82,099 km
# 1922         683   Maruti   Wagon                2017        86,977 km
# 1923         684  Hyundai     i20                2011        23,105 km
#
#        Fuels No. of Owner Variant   Location       Price
# 0     Petrol    1st Owner    GTX+  New Delhi  ₹17,22,000
# ...

# %%
DF2_3.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
DF2_3
# Out:
#         Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0         KIA  SELTOS                2020         5,999 km  Petrol
# 1         KIA  SELTOS                2020         9,417 km  Petrol
# 2     Hyundai   Grand                2019        19,964 km  Petrol
# 3      Maruti    Alto                2011        12,030 km  Petrol
# 4     Hyundai   Grand                2019        20,969 km  Petrol
# ...       ...     ...                 ...              ...     ...
# 1919  Hyundai   Grand                2015        31,857 km  Petrol
# 1920  Hyundai     Eon                2014        30,721 km  Petrol
# 1921   Maruti       A                2011        82,099 km  Petrol
# 1922   Maruti   Wagon                2017        86,977 km     CNG
# 1923  Hyundai     i20                2011        23,105 km  Petrol
#
#      No. of Owner Variant   Location       Price
# 0       1st Owner    GTX+  New Delhi  ₹17,22,000
# 1       1st Owner     GTX  New Delhi  ₹16,81,000
# ...

# %%
DF=[DF2_3,dfCar4]
DF2_4=pd.concat(DF).reset_index(drop=True)
DF2_4
# Out:
#         Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0         KIA  SELTOS                2020         5,999 km  Petrol
# 1         KIA  SELTOS                2020         9,417 km  Petrol
# 2     Hyundai   Grand                2019        19,964 km  Petrol
# 3      Maruti    Alto                2011        12,030 km  Petrol
# 4     Hyundai   Grand                2019        20,969 km  Petrol
# ...       ...     ...                 ...              ...     ...
# 3145  Hyundai   GRAND                2020        15,620 km  Petrol
# 3146    Honda    Brio                2014        17,054 km  Petrol
# 3147   Maruti   Swift                2021        10,975 km  Petrol
# 3148   Datsun      Go                2016        76,598 km  Petrol
# 3149  Hyundai   Verna                2011        81,911 km  Diesel
#
#      No. of Owner  Variant   Location       Price  Unnamed: 0
# 0       1st Owner     GTX+  New Delhi  ₹17,22,000         NaN
# ...

# %%
DF2_4.drop(['Unnamed: 0'],axis=1,inplace=True)
DF2_4
# Out:
#         Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0         KIA  SELTOS                2020         5,999 km  Petrol
# 1         KIA  SELTOS                2020         9,417 km  Petrol
# 2     Hyundai   Grand                2019        19,964 km  Petrol
# 3      Maruti    Alto                2011        12,030 km  Petrol
# 4     Hyundai   Grand                2019        20,969 km  Petrol
# ...       ...     ...                 ...              ...     ...
# 3145  Hyundai   GRAND                2020        15,620 km  Petrol
# 3146    Honda    Brio                2014        17,054 km  Petrol
# 3147   Maruti   Swift                2021        10,975 km  Petrol
# 3148   Datsun      Go                2016        76,598 km  Petrol
# 3149  Hyundai   Verna                2011        81,911 km  Diesel
#
#      No. of Owner  Variant   Location       Price
# 0       1st Owner     GTX+  New Delhi  ₹17,22,000
# 1       1st Owner      GTX  New Delhi  ₹16,81,000
# ...

# %%
DF=[DF2_4,dfCar5]
DF2_5=pd.concat(DF).reset_index(drop=True)
DF2_5
# Out:
#          Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0          KIA  SELTOS                2020         5,999 km  Petrol
# 1          KIA  SELTOS                2020         9,417 km  Petrol
# 2      Hyundai   Grand                2019        19,964 km  Petrol
# 3       Maruti    Alto                2011        12,030 km  Petrol
# 4      Hyundai   Grand                2019        20,969 km  Petrol
# ...        ...     ...                 ...              ...     ...
# 4321     HONDA   AMAZE                2019        20,700 KM  PETROL
# 4322    Maruti  Suzuki                2018        58,200 KM     CNG
# 4323  Mahindra    Thar                2022         1,102 KM  PETROL
# 4324   Renault    Kwid                2019        25,519 KM  PETROL
# 4325    MARUTI  SUZUKI                2019        68,219 KM  DIESEL
#
#      No. of Owner    Variant   Location       Price  Unnamed: 0
# 0       1st Owner       GTX+  New Delhi  ₹17,22,000         NaN
# ...

# %%
DF2_5.drop(['Unnamed: 0'],axis=1,inplace=True)
DF2_5
# Out:
#          Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0          KIA  SELTOS                2020         5,999 km  Petrol
# 1          KIA  SELTOS                2020         9,417 km  Petrol
# 2      Hyundai   Grand                2019        19,964 km  Petrol
# 3       Maruti    Alto                2011        12,030 km  Petrol
# 4      Hyundai   Grand                2019        20,969 km  Petrol
# ...        ...     ...                 ...              ...     ...
# 4321     HONDA   AMAZE                2019        20,700 KM  PETROL
# 4322    Maruti  Suzuki                2018        58,200 KM     CNG
# 4323  Mahindra    Thar                2022         1,102 KM  PETROL
# 4324   Renault    Kwid                2019        25,519 KM  PETROL
# 4325    MARUTI  SUZUKI                2019        68,219 KM  DIESEL
#
#      No. of Owner    Variant   Location       Price
# 0       1st Owner       GTX+  New Delhi  ₹17,22,000
# ...

# %%
DF=[DF2_5,dfCar6]
DF2_6=pd.concat(DF).reset_index(drop=True)
DF2_6
# Out:
#         Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0         KIA  SELTOS                2020         5,999 km  Petrol
# 1         KIA  SELTOS                2020         9,417 km  Petrol
# 2     Hyundai   Grand                2019        19,964 km  Petrol
# 3      Maruti    Alto                2011        12,030 km  Petrol
# 4     Hyundai   Grand                2019        20,969 km  Petrol
# ...       ...     ...                 ...              ...     ...
# 4540   Maruti  Suzuki                2014        93,199 KM  PETROL
# 4541   MARUTI  SUZUKI                2018        11,060 KM  PETROL
# 4542  Hyundai   Elite                2018        40,897 KM  PETROL
# 4543   Maruti  Suzuki                2020         8,246 KM  PETROL
# 4544  Hyundai     i20                2015        72,727 KM  PETROL
#
#      No. of Owner    Variant   Location       Price  Unnamed: 0
# 0       1st Owner       GTX+  New Delhi  ₹17,22,000         NaN
# ...

# %%
DF2_6.drop(['Unnamed: 0'],axis=1,inplace=True)
DF2_6
# Out:
#         Brand   Model  Manufacturing Year Driven Kilometer   Fuels  \
# 0         KIA  SELTOS                2020         5,999 km  Petrol
# 1         KIA  SELTOS                2020         9,417 km  Petrol
# 2     Hyundai   Grand                2019        19,964 km  Petrol
# 3      Maruti    Alto                2011        12,030 km  Petrol
# 4     Hyundai   Grand                2019        20,969 km  Petrol
# ...       ...     ...                 ...              ...     ...
# 4540   Maruti  Suzuki                2014        93,199 KM  PETROL
# 4541   MARUTI  SUZUKI                2018        11,060 KM  PETROL
# 4542  Hyundai   Elite                2018        40,897 KM  PETROL
# 4543   Maruti  Suzuki                2020         8,246 KM  PETROL
# 4544  Hyundai     i20                2015        72,727 KM  PETROL
#
#      No. of Owner    Variant   Location       Price
# 0       1st Owner       GTX+  New Delhi  ₹17,22,000
# 1       1st Owner        GTX  New Delhi  ₹16,81,000
# ...

# %% [markdown]
# # Last Chapter (Noida)

# %%
url=('https://www.cars24.com/buy-used-car?sort=P&serveWarrantyCount=true&gaId=11487337.1675431892&storeCityId=134&pinId=201301')
driver.get(url)

# %%
Manufacturing_year =[]
years=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    
    for i in years:
        
        Manufacturing_year.append(i.text.split()[0])
        

except NoSuchElementException:
    
    Manufacturing_year.append('Not Present')
    
Manufacturing_year
# Out:
# ['2015',
#  '2020',
#  '2011',
#  '2012',
#  '2011',
#  '2019',
#  '2018',
#  '2020',
#  '2022',
#  '2011',
#  '2021',
#  '2015',
#  '2019',
#  '2013',
#  '2011',
#  '2018',
#  '2014',
#  '2020',
#  '2017',
#  '2017',
#  '2019',
#  '2011',
#  '2020',
#  '2015',
#  '2019',
#  '2010',
#  '2016',
#  '2011',
#  '2014',
#  '2014',
#  '2021',
#  '2019',
#  '2011',
#  '2020',
#  '2020',
#  '2013',
#  '2014',
#  '2021',
#  '2019',
#  '2012',
#  '2022',
#  '2013',
#  '2012',
#  '2012',
#  '2019',
#  '2014',
#  '2013',
#  '2013',
#  '2018',
#  '2019',
#  '2011',
#  '2018',
#  '2016',
#  '2019',
#  '2015',
#  '2018',
#  '2014',
#  '2021',
#  '2016',
#  '2014',
#  '2014',
#  '2021',
#  '2019',
#  '2017',
#  '2014',
#  '2017',
#  '2019',
#  '2015',
#  '2020',
#  '2020',
#  '2012',
#  '2015',
#  '2011',
#  '2015',
#  '2020',
#  '2020',
#  '2020',
#  '2014',
#  '2018',
#  '2015',
#  '2019',
#  '2016',
#  '2019',
#  '2013',
#  '2016',
#  '2019',
#  '2020',
#  '2015',
#  '2017',
#  '2017',
# ...

# %%
len(Manufacturing_year)
# Out:
# 1180

# %%
Brands=[]
brand=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    for i in brand:
        Brands.append(i.text.split()[1])
except NoSuchElementException:
    Brands.append('Not Present')
    
Brands
# Out:
# ['Honda',
#  'HYUNDAI',
#  'Maruti',
#  'HYUNDAI',
#  'Hyundai',
#  'Honda',
#  'Maruti',
#  'KIA',
#  'SKODA',
#  'Maruti',
#  'KIA',
#  'Toyota',
#  'Honda',
#  'HYUNDAI',
#  'MARUTI',
#  'Honda',
#  'Honda',
#  'Skoda',
#  'Honda',
#  'MARUTI',
#  'Mahindra',
#  'Maruti',
#  'VOLKSWAGEN',
#  'Maruti',
#  'HYUNDAI',
#  'HYUNDAI',
#  'Renault',
#  'Maruti',
#  'MARUTI',
#  'MARUTI',
#  'Skoda',
#  'Jeep',
#  'MARUTI',
#  'KIA',
#  'Skoda',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Jeep',
#  'HONDA',
#  'KIA',
#  'HYUNDAI',
#  'Hyundai',
#  'Honda',
#  'HONDA',
#  'HONDA',
#  'Honda',
#  'HONDA',
#  'Honda',
#  'Hyundai',
#  'Honda',
#  'HONDA',
#  'FORD',
#  'Maruti',
#  'HONDA',
#  'MARUTI',
#  'Hyundai',
#  'Maruti',
#  'Maruti',
#  'Ford',
#  'Honda',
#  'Renault',
#  'Toyota',
#  'Maruti',
#  'Hyundai',
#  'Honda',
#  'Honda',
#  'HONDA',
#  'Maruti',
#  'KIA',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Honda',
#  'Skoda',
#  'Toyota',
#  'KIA',
#  'HONDA',
#  'Maruti',
# ...

# %%
Model=[]
models=driver.find_elements(By.CLASS_NAME,"_2lmIw")
try:
    for i in models:
        Model.append(i.text.split()[2])
except NoSuchElementException:
    Model.append('Not Present')
    
Model
# Out:
# ['Amaze',
#  'GRAND',
#  'Suzuki',
#  'I10',
#  'i10',
#  'Amaze',
#  'Suzuki',
#  'SONET',
#  'KUSHAQ',
#  'Suzuki',
#  'SONET',
#  'Camry',
#  'Amaze',
#  'I20',
#  'SUZUKI',
#  'City',
#  'Amaze',
#  'Rapid',
#  'City',
#  'SUZUKI',
#  'XUV500',
#  'Swift',
#  'POLO',
#  'Alto',
#  'CRETA',
#  'I10',
#  'Kwid',
#  'Suzuki',
#  'SUZUKI',
#  'SUZUKI',
#  'KUSHAQ',
#  'Compass',
#  'SUZUKI',
#  'SONET',
#  'Rapid',
#  'Suzuki',
#  'SANTRO',
#  'VENUE',
#  'Compass',
#  'CITY',
#  'CARENS',
#  'I20',
#  'i10',
#  'Brio',
#  'CITY',
#  'CITY',
#  'City',
#  'CITY',
#  'City',
#  'Grand',
#  'City',
#  'CITY',
#  'ECOSPORT',
#  'Suzuki',
#  'AMAZE',
#  'BALENO',
#  'i20',
#  'Suzuki',
#  'Suzuki',
#  'Ecosport',
#  'Amaze',
#  'Kiger',
#  'INNOVA',
#  'Suzuki',
#  'Grand',
#  'City',
#  'Amaze',
#  'CITY',
#  'Suzuki',
#  'SELTOS',
#  'Suzuki',
#  'Xcent',
#  'Suzuki',
#  'City',
#  'Rapid',
#  'URBAN',
#  'SELTOS',
#  'CITY',
#  'Suzuki',
#  'Grand',
#  'City',
#  'Jazz',
#  'AMAZE',
# ...

# %%
Variant=[]
variant=driver.find_elements(By.CLASS_NAME,"_1hOnS")

try:
    for i in variant:
        Variant.append(i.text.split()[0])
        
except NoSuchElementException:
    Variant.append('Not Present')
    
Variant
# Out:
# ['1.2',
#  'MAGNA',
#  'VXIManual',
#  'MAGNA',
#  'MAGNA',
#  '1.2',
#  'ALPHA',
#  'GTX',
#  'STYLE',
#  'VXIManual',
#  'GTX',
#  '2.5',
#  '1.2',
#  'SPORTZ',
#  'LXIManual',
#  'V',
#  '1.2',
#  '1.0',
#  'V',
#  'VXIManual',
#  'W11',
#  'ZXIManual',
#  'COMFORTLINE',
#  'VXI',
#  '1.4',
#  'ERA',
#  '1.0',
#  'VXIManual',
#  'LXIManual',
#  'VXIManual',
#  'STYLE',
#  '2.0',
#  'LXIManual',
#  'GTX',
#  'ACTIVE',
#  'VXIManual',
#  'GL',
#  'S',
#  '1.4',
#  '1.5L',
#  'LUXURY',
#  'MAGNA',
#  'SPORTZ',
#  '1.2',
#  'ZX',
#  'SV',
#  'S',
#  '1.5',
#  'V',
#  'MAGNA',
#  'S',
#  'V',
#  '1.5AMBIENTE',
#  'LXIManual',
#  '1.2',
#  'DELTA',
#  'SPORTZ',
#  'LXI',
#  'DELTA',
#  '1.5',
#  '1.2',
#  'RXZ',
#  '2.8',
#  'LXIManual',
#  'MAGNA',
#  'V',
#  '1.2',
#  'SV',
#  'VXIManual',
#  'GTX+',
#  'LXIManual',
#  'S',
#  'VXIManual',
#  'VX',
#  '1.0',
#  'Premium',
#  'GTX',
#  '1.5L',
#  'ALPHA',
#  'SPORTZ',
#  'SV',
#  '1.2',
#  '1.2',
#  'SPORTZ',
#  'VX',
#  '1.2',
# ...

# %%
Driven_kilometers=[]
kilometer=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[1]")
try:
    for i in kilometer:
        Driven_kilometers.append(i.text)
        
except NoSuchElementException:
    Driven_kilometers.append('Not Present')
    
Driven_kilometers
# Out:
# ['28,570 KM',
#  '13,851 KM',
#  '33,528 KM',
#  '48,677 KM',
#  '32,648 KM',
#  '15,119 KM',
#  '60,583 KM',
#  '12,835 KM',
#  '2,696 KM',
#  '28,979 KM',
#  '6,978 KM',
#  '93,626 KM',
#  '28,171 KM',
#  '56,159 KM',
#  '80,212 KM',
#  '31,912 KM',
#  '27,324 KM',
#  '55,144 KM',
#  '58,982 KM',
#  '16,846 KM',
#  '23,017 KM',
#  '79,489 KM',
#  '22,311 KM',
#  '45,436 KM',
#  '75,115 KM',
#  '46,523 KM',
#  '16,545 KM',
#  '22,754 KM',
#  '6,920 KM',
#  '21,670 KM',
#  '7,182 KM',
#  '47,136 KM',
#  '73,738 KM',
#  '12,461 KM',
#  '18,953 KM',
#  '68,674 KM',
#  '43,944 KM',
#  '6,063 KM',
#  '23,690 KM',
#  '40,745 KM',
#  '3,084 KM',
#  '37,099 KM',
#  '50,377 KM',
#  '52,532 KM',
#  '99,460 KM',
#  '40,756 KM',
#  '45,482 KM',
#  '32,933 KM',
#  '49,089 KM',
#  '19,964 KM',
#  '52,408 KM',
#  '71,080 KM',
#  '63,068 KM',
#  '1,994 KM',
#  '21,789 KM',
#  '26,972 KM',
#  '59,025 KM',
#  '3,995 KM',
#  '14,822 KM',
#  '53,872 KM',
#  '50,821 KM',
#  '2,461 KM',
#  '49,585 KM',
# ...

# %%
No_of_owners=[]
owner=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[2]")
try:
    for i in owner:
        
        No_of_owners.append(i.text)
except NoSuchElementException:
    No_of_owner.append('Not Present')
    
No_of_owners
# Out:
# ['1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '2ND OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
#  '1ST OWNER',
# ...

# %%
Fuel=[]
fuel=driver.find_elements(By.XPATH,"//ul[@class='_13yb6']/li[3]")
try:
    for i in fuel:
        Fuel.append(i.text)
        
except NoSuchElementException:
    
    Fuel.append('Not Present')
Fuel
# Out:
# ['PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
# ...

# %%
Price=[]
price=driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹4,38,000',
#  '₹5,29,000',
#  '₹2,74,000',
#  '₹2,55,000',
#  '₹2,51,000',
#  '₹6,70,000',
#  '₹9,10,000',
#  '₹13,38,000',
#  '₹18,48,000',
#  '₹2,67,000',
#  '₹12,62,000',
#  '₹12,43,000',
#  '₹5,92,000',
#  '₹3,82,000',
#  '₹2,85,000',
#  '₹9,02,000',
#  '₹4,07,000',
#  '₹9,54,000',
#  '₹7,95,000',
#  '₹3,33,000',
#  '₹15,66,000',
#  '₹3,10,000',
#  '₹6,53,000',
#  '₹3,16,000',
#  '₹8,90,000',
#  '₹1,68,000',
#  '₹2,69,000',
#  '₹2,53,000',
#  '₹2,72,000',
#  '₹2,78,000',
#  '₹17,01,000',
#  '₹16,67,000',
#  '₹2,70,000',
#  '₹13,39,000',
#  '₹8,85,000',
#  '₹2,64,000',
#  '₹2,86,000',
#  '₹8,74,000',
#  '₹18,79,000',
#  '₹4,01,000',
#  '₹17,42,000',
#  '₹3,94,000',
#  '₹2,63,000',
#  '₹2,47,000',
#  '₹9,25,000',
#  '₹5,51,000',
#  '₹5,22,000',
#  '₹4,76,000',
#  '₹8,81,000',
#  '₹5,03,000',
#  '₹3,16,000',
#  '₹7,82,000',
#  '₹5,88,000',
#  '₹5,66,000',
#  '₹4,72,000',
#  '₹5,50,000',
#  '₹4,49,000',
#  '₹5,17,000',
#  '₹5,32,000',
#  '₹5,04,000',
#  '₹4,01,000',
# ...

# %%
len(Price)
# Out:
# 1180

# %%
Location=[]
location=['Noida']
Location=location*1180
len(Location)
# Out:
# 1180

# %%
len(Price),len(Location),len(Fuel),len(No_of_owners),len(Driven_kilometers),len(Variant),len(Model),len(Brands),len(Manufacturing_year)
# Out:
# (1180, 1180, 1180, 1180, 1180, 1180, 1180, 1180, 1180)

# %%
Car7=pd.DataFrame({"Brand":Brands,"Model":Model,"Manufacturing Year":Manufacturing_year,"Driven Kilometer":Driven_kilometers,"Fuels":Fuel,"No. of Owner":No_of_owners,"Variant":Variant,"Location":Location,"Price":Price})
Car7
# Out:
#          Brand   Model Manufacturing Year Driven Kilometer   Fuels  \
# 0        Honda   Amaze               2015        28,570 KM  PETROL
# 1      HYUNDAI   GRAND               2020        13,851 KM  PETROL
# 2       Maruti  Suzuki               2011        33,528 KM  PETROL
# 3      HYUNDAI     I10               2012        48,677 KM  PETROL
# 4      Hyundai     i10               2011        32,648 KM  PETROL
# ...        ...     ...                ...              ...     ...
# 1175     HONDA   AMAZE               2019        20,700 KM  PETROL
# 1176    Maruti  Suzuki               2011        29,838 KM  PETROL
# 1177    Maruti  Suzuki               2018        58,200 KM     CNG
# 1178  Mahindra    Thar               2022         1,102 KM  PETROL
# 1179   Renault    Kwid               2019        25,519 KM  PETROL
#
#      No. of Owner    Variant Location       Price
# 0       1ST OWNER        1.2    Noida   ₹4,38,000
# 1       2ND OWNER      MAGNA    Noida   ₹5,29,000
# ...

# %%
DF=[DF2_5,Car7]
DF2_7=pd.concat(DF).reset_index(drop=True)
DF2_7
# Out:
#          Brand   Model Manufacturing Year Driven Kilometer   Fuels  \
# 0          KIA  SELTOS               2020         5,999 km  Petrol
# 1          KIA  SELTOS               2020         9,417 km  Petrol
# 2      Hyundai   Grand               2019        19,964 km  Petrol
# 3       Maruti    Alto               2011        12,030 km  Petrol
# 4      Hyundai   Grand               2019        20,969 km  Petrol
# ...        ...     ...                ...              ...     ...
# 5501     HONDA   AMAZE               2019        20,700 KM  PETROL
# 5502    Maruti  Suzuki               2011        29,838 KM  PETROL
# 5503    Maruti  Suzuki               2018        58,200 KM     CNG
# 5504  Mahindra    Thar               2022         1,102 KM  PETROL
# 5505   Renault    Kwid               2019        25,519 KM  PETROL
#
#      No. of Owner    Variant   Location       Price
# 0       1st Owner       GTX+  New Delhi  ₹17,22,000
# 1       1st Owner        GTX  New Delhi  ₹16,81,000
# ...

# %%
DF2_7.to_csv('Car_Prediction.csv')
